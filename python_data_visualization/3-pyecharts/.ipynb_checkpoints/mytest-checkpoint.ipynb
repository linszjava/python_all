# %%
import ijson
from pyecharts.charts import Graph
from pyecharts import options as opts
import pandas as pd

data = pd.read_json('hanyu.json',encoding='utf_8')
data['Package']['PersonAuthority']['PersonInfo']['Person'][0]['PersonSocialAssociation']
# Out:
# {'Association': [{'AssocPersonId': '3605',
#    'AssocPersonName': '柳宗元',
#    'AssocCode': '9',
#    'AssocName': '友',
#    'Year': '',
#    'TextTitle': '[n/a]',
#    'KinPersonId': '0',
#    'KinPersonName': '未詳',
#    'KinRelName': '未詳',
#    'AssocKinPersonId': '0',
#    'AssocKinPersonName': '未詳',
#    'AssocKinRelName': '未詳',
#    'Source': '人名權威資料（中央研究院歷史語言研究所）',
#    'Pages': '18182',
#    'Notes': ''},
#   {'AssocPersonId': '13575',
#    'AssocPersonName': '張籍',
#    'AssocCode': '9',
#    'AssocName': '友',
#    'Year': '',
#    'TextTitle': '[n/a]',
#    'KinPersonId': '0',
#    'KinPersonName': '未詳',
#    'KinRelName': '未詳',
#    'AssocKinPersonId': '0',
#    'AssocKinPersonName': '未詳',
#    'AssocKinRelName': '未詳',
#    'Source': '人名權威資料（中央研究院歷史語言研究所）',
#    'Pages': '18182',
#    'Notes': ''},
#   {'AssocPersonId': '32248',
#    'AssocPersonName': '元稹',
#    'AssocCode': '9',
#    'AssocName': '友',
#    'Year': '',
#    'TextTitle': '[n/a]',
#    'KinPersonId': '0',
# ...
